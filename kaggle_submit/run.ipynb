# %%
# !pip install bitsandbytes accelerate datasets transformers wandb

# %%
with open('train.py', 'w') as f:
    f.write(open('../train.py', 'r').read() if __import__('os').path.exists('../train.py') else open('train.py', 'r').read())

# %%
# !python train.py
